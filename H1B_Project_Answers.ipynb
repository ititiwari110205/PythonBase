# %% [markdown]
# ## Write Code in Empty cells don't use existing cells otherwise output will be earesed use new cells to write code

# %% [markdown]
# #### Import Related Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### read csv in Pandas DataFrame

# %%
df = pd.read_csv("C:\\Users\\shubh\\Downloads\\h1b_kaggle.csv\\h1b_kaggle.csv")

# %%
df.head()
# Out:
#    Unnamed: 0          CASE_STATUS  \
# 0           1  CERTIFIED-WITHDRAWN
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %% [markdown]
# ### show columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ### delete 'unnamed:0'  column from data set

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df.columns
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ## check no of rows in data frame

# %%
df.shape[0]
# Out:
# 3002458

# %%
# Out:
# 3002458

# %% [markdown]
# ## Drop All rows which has any NA value and show first 5 rows after this operation

# %%
df.dropna(inplace=True)
df.head()
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE  \
# ...

# %%
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR                 WORKSITE  \
# ...

# %% [markdown]
# ## reset index and check how many rows you have

# %%
df.reset_index(inplace=True)
df.shape[0]
# Out:
# 2877765

# %%
# Out:
# 2877765

# %% [markdown]
# ## Write a code to find out top 15 hiring company (Employer Name)

# %%
top_hirings = df['EMPLOYER_NAME'].value_counts().head(15)
top_hirings
# Out:
# EMPLOYER_NAME
# INFOSYS LIMITED                                    130257
# TATA CONSULTANCY SERVICES LIMITED                   64273
# WIPRO LIMITED                                       45673
# DELOITTE CONSULTING LLP                             35999
# IBM INDIA PRIVATE LIMITED                           33585
# ACCENTURE LLP                                       33226
# MICROSOFT CORPORATION                               25551
# HCL AMERICA, INC.                                   22488
# ERNST & YOUNG U.S. LLP                              18094
# COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION     17322
# CAPGEMINI AMERICA INC                               16628
# GOOGLE INC.                                         16425
# LARSEN & TOUBRO INFOTECH LIMITED                    14318
# IGATE TECHNOLOGIES INC.                             12327
# IBM CORPORATION                                     11976
# Name: count, dtype: int64

# %%
# Out:
# INFOSYS LIMITED                      130257
# TATA CONSULTANCY SERVICES LIMITED     64273
# WIPRO LIMITED                         45673
# DELOITTE CONSULTING LLP               35999
# IBM INDIA PRIVATE LIMITED             33585
# Name: EMPLOYER_NAME, dtype: int64

# %%
plt.figure(figsize=(5, 3))
top_hirings.plot(kind='bar', color=['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'blue', 'orange', 'green', 'red', 'purple'])
plt.title('Top 15 Hiring Companies')
plt.xticks(rotation=90,fontsize =8)
plt.show()

# %% [markdown]
# ### Top 15 companies which provide highest PREVALING WAGE

# %%
top_wages = df.groupby('EMPLOYER_NAME')['PREVAILING_WAGE'].mean().nlargest(15)
top_wages
# Out:
# EMPLOYER_NAME
# OMPI OF AMERICA INC.                           2.129878e+08
# INNOBOX SYSTEMS                                1.723634e+08
# BAALAAJEE INC.                                 1.434408e+08
# DEPARTMENT OF VETERANS AFFAIRS/NMVAHCS         1.347021e+08
# BAYSHORE GLOBAL MANAGEMENT LLC                 1.262358e+08
# MANHATTAN SOFTWARE, INC.                       1.239077e+08
# GYM-PACT CORP                                  1.233898e+08
# BOOKRENTER.COM, INC.                           1.230321e+08
# CATANIA, MAHON, MILLIGRAM &AMP; RIDER, PLLC    1.226971e+08
# AGROPLASMA, INC                                1.221334e+08
# AQUA LUNG AMERICA INC.                         1.181107e+08
# AV INVESTMENT COMPANY, INC.                    1.159038e+08
# BRONX LIGHTHOUSE CHARTER SCHOOL                1.124240e+08
# E AND D MEDIA INC.                             1.098240e+08
# TAMPA BAY DIGITAL DESIGN EXPERTS, LLC          1.070435e+08
# Name: PREVAILING_WAGE, dtype: float64

# %%
# Out:
# 60000.0    10185
# 55245.0     6745
# 62566.0     6480
# 58053.0     5683
# 52499.0     5492
# Name: PREVAILING_WAGE, dtype: int64

# %% [markdown]
# ##### Average PREVAILING WAGE

# %%
df['PREVAILING_WAGE'].mean()
# Out:
# 145166.64888401062

# %%
# Out:
# 145166.64888402403

# %%
plt.figure(figsize=(5, 3))
top_wages.plot(kind='bar', color=['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'blue', 'orange', 'green', 'red', 'purple'])
plt.xticks(rotation=90,fontsize =8)
plt.show()

# %%
df.columns
# Out:
# Index(['index', 'CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %%
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ### Top 20 WORKSITE

# %%
top_worksite = df['WORKSITE'].value_counts().head(20)
top_worksite
# Out:
# WORKSITE
# NEW YORK, NEW YORK            190863
# HOUSTON, TEXAS                 83385
# SAN FRANCISCO, CALIFORNIA      62457
# ATLANTA, GEORGIA               52008
# CHICAGO, ILLINOIS              51167
# SAN JOSE, CALIFORNIA           49582
# SUNNYVALE, CALIFORNIA          34968
# DALLAS, TEXAS                  31509
# BOSTON, MASSACHUSETTS          31336
# REDMOND, WASHINGTON            30574
# CHARLOTTE, NORTH CAROLINA      30176
# IRVING, TEXAS                  29316
# MOUNTAIN VIEW, CALIFORNIA      29245
# SAN DIEGO, CALIFORNIA          28656
# SANTA CLARA, CALIFORNIA        27945
# JERSEY CITY, NEW JERSEY        26822
# SEATTLE, WASHINGTON            26745
# AUSTIN, TEXAS                  26695
# LOS ANGELES, CALIFORNIA        26393
# PHILADELPHIA, PENNSYLVANIA     24104
# Name: count, dtype: int64

# %%
# Out:
# NEW YORK, NEW YORK            190863
# HOUSTON, TEXAS                 83385
# SAN FRANCISCO, CALIFORNIA      62457
# ATLANTA, GEORGIA               52008
# CHICAGO, ILLINOIS              51167
# SAN JOSE, CALIFORNIA           49582
# SUNNYVALE, CALIFORNIA          34968
# DALLAS, TEXAS                  31509
# BOSTON, MASSACHUSETTS          31336
# REDMOND, WASHINGTON            30574
# CHARLOTTE, NORTH CAROLINA      30176
# IRVING, TEXAS                  29316
# MOUNTAIN VIEW, CALIFORNIA      29245
# SAN DIEGO, CALIFORNIA          28656
# SANTA CLARA, CALIFORNIA        27945
# JERSEY CITY, NEW JERSEY        26822
# SEATTLE, WASHINGTON            26745
# AUSTIN, TEXAS                  26695
# LOS ANGELES, CALIFORNIA        26393
# PHILADELPHIA, PENNSYLVANIA     24104
# Name: WORKSITE, dtype: int64

# %%
plt.figure(figsize=(5, 3))
top_worksite.plot(kind='bar', color=['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'blue','skyblue', 'orange', 'green', 'red', 'purple','brown','pink','gray','yellow'])
plt.xticks(rotation=90,fontsize =8)
plt.show()

# %% [markdown]
# ### head of Worksite Column

# %%
df['WORKSITE'].head()
# Out:
# 0        ANN ARBOR, MICHIGAN
# 1               PLANO, TEXAS
# 2    JERSEY CITY, NEW JERSEY
# 3           DENVER, COLORADO
# 4        ST. LOUIS, MISSOURI
# Name: WORKSITE, dtype: object

# %%
# Out:
# 0        ANN ARBOR, MICHIGAN
# 1               PLANO, TEXAS
# 2    JERSEY CITY, NEW JERSEY
# 3           DENVER, COLORADO
# 4        ST. LOUIS, MISSOURI
# Name: WORKSITE, dtype: object

# %% [markdown]
# ### Show Column Names

# %%
df.columns
# Out:
# Index(['index', 'CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %%
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# ### Apply a Function on DataFrame to gather only State Name from Worksite
#
#     eg. worksite name current -  SAN FRANCISCO, CALIFORNIA
#         worksite name after - CALIFORNIA
#
# **note**: there sholud not be any space at the begning or end of worksite name

# %%
def states(worksite):
    return worksite.split(',')[-1].strip()
    

df['WORKSITE']=df['WORKSITE'].apply(states)
df.head()
# Out:
#    index          CASE_STATUS  \
# 0      0  CERTIFIED-WITHDRAWN
# 1      1  CERTIFIED-WITHDRAWN
# 2      2  CERTIFIED-WITHDRAWN
# 3      3  CERTIFIED-WITHDRAWN
# 4      4            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %%
# Out:
#            CASE_STATUS                                      EMPLOYER_NAME  \
# 0  CERTIFIED-WITHDRAWN                             UNIVERSITY OF MICHIGAN
# 1  CERTIFIED-WITHDRAWN                             GOODMAN NETWORKS, INC.
# 2  CERTIFIED-WITHDRAWN                          PORTS AMERICA GROUP, INC.
# 3  CERTIFIED-WITHDRAWN  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4            WITHDRAWN                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
#   FULL_TIME_POSITION  PREVAILING_WAGE    YEAR    WORKSITE         lon  \
# ...

# %% [markdown]
# **note:** if you view your analysis than you will find that 'MARIANA ISLANDS' worksite name is replaced with NA values

# %% [markdown]
# ### Replace all NA records in your Worksite Column with Value  'MARIANA ISLANDS'

# %%
def naToMAR(worksite):
    if worksite == 'NA':
        return 'MARIANA ISLANDS'
    else:
        return worksite

df['WORKSITE'] = df['WORKSITE'].apply(naToMAR)
df[df['WORKSITE']=='MARIANA ISLANDS']
# Out:
#            index CASE_STATUS  \
# 191          212   CERTIFIED
# 262          294   WITHDRAWN
# 264          297   WITHDRAWN
# 271          304   WITHDRAWN
# 274          307   CERTIFIED
# ...          ...         ...
# 2877110  3001749      DENIED
# 2877200  3001846      DENIED
# 2877227  3001874      DENIED
# 2877619  3002290      DENIED
# 2877626  3002297      DENIED
#
#                                              EMPLOYER_NAME  \
# 191                ALTISOURCE ASSET MANAGEMENT CORPORATION
# 262                    IMPERIAL PACIFIC INTERNATIONAL CNMI
# 264                    IMPERIAL PACIFIC INTERNATIONAL CNMI
# 271                    IMPERIAL PACIFIC INTERNATIONAL CNMI
# 274                    IMPERIAL PACIFIC INTERNATIONAL CNMI
# ...                                                    ...
# 2877110                        TUMON BAY RESORT & SPA, LLC
# 2877200                       PSG PROFESSIONAL CORPORATION
# 2877227  VEOLIA WATER NORTH AMERICA OPERATING SERVICES,...
# ...

# %% [markdown]
# ### Print out how many unique Worksites are there

# %%
len(df['WORKSITE'].unique())
# Out:
# 53

# %%
# Out:
# 53

# %% [markdown]
# ##### show column names

# %%
df.columns
# Out:
# Index(['index', 'CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %%
# Out:
# Index(['CASE_STATUS', 'EMPLOYER_NAME', 'SOC_NAME', 'JOB_TITLE',
#        'FULL_TIME_POSITION', 'PREVAILING_WAGE', 'YEAR', 'WORKSITE', 'lon',
#        'lat'],
#       dtype='object')

# %% [markdown]
# #### Rename you column names as
#
#     {'EMPLOYER_NAME':'EMPLOYER','FULL_TIME_POSITION':'FULL_T','PREVAILING_WAGE':'PREV_WAGE','WORKSITE':'STATE','lon':'LON','lat':'LAT'}

# %%
df.rename(columns={'EMPLOYER_NAME':'EMPLOYER','FULL_TIME_POSITION':'FULL_T','PREVAILING_WAGE':'PREV_WAGE','WORKSITE':'STATE','lon':'LON','lat':'LAT'},inplace=True)

# %% [markdown]
# #### Now Remove all Columns Except these columns
#
#     'CASE_STATUS','YEAR','STATE','SOC_NAME','JOB_TITLE','FULL_T','PREV_WAGE','EMPLOYER','LON',"LAT"

# %%
df = df.loc[:,['CASE_STATUS','YEAR','STATE','SOC_NAME','JOB_TITLE','FULL_T','PREV_WAGE','EMPLOYER','LON',"LAT"]]

# %% [markdown]
# __show colnames__

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'YEAR', 'STATE', 'SOC_NAME', 'JOB_TITLE', 'FULL_T',
#        'PREV_WAGE', 'EMPLOYER', 'LON', 'LAT'],
#       dtype='object')

# %%
# Out:
# Index(['CASE_STATUS', 'YEAR', 'STATE', 'SOC_NAME', 'JOB_TITLE', 'FULL_T',
#        'PREV_WAGE', 'EMPLOYER', 'LON', 'LAT'],
#       dtype='object')

# %% [markdown]
# #### Perform These Operations
#
#     Precise LON and LAT columns upto 2 decimal palaces
#
#     Convert YEAR Column into String
#
#     Convert PREV_WAGE column into Integer

# %%
df['LON'] = df['LON'].round(2)
df['LAT'] = df['LAT'].round(2)

# %%
df['YEAR'] = df['YEAR'].astype(float).astype(int).astype(str)
df['PREV_WAGE'] = df['PREV_WAGE'].astype(int)

# %% [markdown]
# __show top 3 values to check above operations__

# %%
df.head(3)
# Out:
#            CASE_STATUS  YEAR       STATE                       SOC_NAME  \
# 0  CERTIFIED-WITHDRAWN  2016    MICHIGAN  BIOCHEMISTS AND BIOPHYSICISTS
# 1  CERTIFIED-WITHDRAWN  2016       TEXAS               CHIEF EXECUTIVES
# 2  CERTIFIED-WITHDRAWN  2016  NEW JERSEY               CHIEF EXECUTIVES
#
#                       JOB_TITLE FULL_T  PREV_WAGE                   EMPLOYER  \
# 0  POSTDOCTORAL RESEARCH FELLOW      N      36067     UNIVERSITY OF MICHIGAN
# 1       CHIEF OPERATING OFFICER      Y     242674     GOODMAN NETWORKS, INC.
# 2         CHIEF PROCESS OFFICER      Y     193066  PORTS AMERICA GROUP, INC.
#
#      LON    LAT
# 0 -83.74  42.28
# 1 -96.70  33.02
# 2 -74.08  40.73

# %%
# Out:
#            CASE_STATUS  YEAR       STATE                       SOC_NAME  \
# 0  CERTIFIED-WITHDRAWN  2016    MICHIGAN  BIOCHEMISTS AND BIOPHYSICISTS
# 1  CERTIFIED-WITHDRAWN  2016       TEXAS               CHIEF EXECUTIVES
# 2  CERTIFIED-WITHDRAWN  2016  NEW JERSEY               CHIEF EXECUTIVES
#
#                       JOB_TITLE FULL_T PREV_WAGE                   EMPLOYER  \
# 0  POSTDOCTORAL RESEARCH FELLOW      N     36067     UNIVERSITY OF MICHIGAN
# 1       CHIEF OPERATING OFFICER      Y    242674     GOODMAN NETWORKS, INC.
# 2         CHIEF PROCESS OFFICER      Y    193066  PORTS AMERICA GROUP, INC.
#
#      LON    LAT
# 0 -83.74  42.28
# 1 -96.70  33.02
# 2 -74.08  40.73

# %% [markdown]
# ### __show unique values of CASE_STATUS Column__

# %%
df['CASE_STATUS'].unique()
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED'], dtype=object)

# %%
# Out:
# array(['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED',
#        'REJECTED', 'INVALIDATED',
#        'PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED'], dtype=object)

# %% [markdown]
# # Calculate the petitions distributions by status

# %%
pet_count = df['CASE_STATUS'].value_counts()
pet_count.tolist()
# Out:
# [2512114, 195721, 85161, 84752, 15, 1, 1]

# %%
# Out:
# [195721, 84752, 2512114, 85161, 1, 1, 15]

# %%
from matplotlib.pyplot import pie,axis,show
import matplotlib as mpl

# %% [markdown]
# #### PETITIONS BY CASE STATUS

# %%
plt.figure(figsize=(5, 5))
plt.pie(pet_count,labels=['CERTIFIED-WITHDRAWN', 'WITHDRAWN', 'CERTIFIED', 'DENIED','','',''], 
        colors=['green', 'orange', 'blue', 'red','yellow','grey'],startangle=30)

plt.title('Petitions by Case Status')
# Out:
# Text(0.5, 1.0, 'Petitions by Case Status')

# %% [markdown]
# # Calculating the petitions distributions by year

# %%
pet_by_year = df['YEAR'].value_counts().sort_index()
pet_by_year.tolist()
# Out:
# [333625, 394267, 422427, 498027, 600120, 629299]

# %%
# Out:
# [333625, 394267, 422427, 498027, 600120, 629299]

# %%
plt.figure(figsize=(8, 3))
pet_by_year.plot(kind='bar', color=['blue', 'orange', 'green', 'red', 'purple', 'brown'])
plt.title('petitions distributions by year')
plt.xticks(rotation=0,fontsize =8)
plt.show()

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
sns.set_context("notebook",font_scale=1.0)
plt.figure(figsize=(13,3))
plt.title('petitions distributions by year')
sns.countplot(x='YEAR',data=df,palette='deep',order=sorted(df['YEAR'].unique()))
# Out:
# <Axes: title={'center': 'petitions distributions by year'}, xlabel='YEAR', ylabel='count'>

# %%
denied = df[df.CASE_STATUS == 'DENIED']
len(denied)
# Out:
# 85161

# %%
del denied['CASE_STATUS']

# %%
denied = denied.reset_index()
denied.head(3)
# Out:
#    index  YEAR       STATE          SOC_NAME  \
# 0     37  2016  WASHINGTON  CHIEF EXECUTIVES
# 1     44  2016  CALIFORNIA  CHIEF EXECUTIVES
# 2     87  2016    ILLINOIS  CHIEF EXECUTIVES
#
#                                            JOB_TITLE FULL_T  PREV_WAGE  \
# 0                            CHIEF EXECUTIVE OFFICER      Y     187200
# 1                                          PRESIDENT      Y     197683
# 2  PRINCIPAL (ATTORNEY) AND CHAIRMAN OF THE EXECU...      Y     226699
#
#                EMPLOYER     LON    LAT
# 0       PARALLELS, INC. -122.22  47.48
# 1  RANCHO LA PUERTA LLC -117.16  32.72
# 2   BAKER & MCKENZIE PC  -87.63  41.88

# %%
denied_year_count = [0]* 6

# %%
years = sorted(df['YEAR'].unique())
for i in range(0,6):
    denied_year_count[i] = denied[denied.YEAR == years[i]]['YEAR'].count()

# %%
denied_year_count
# Out:
# [25986, 18866, 10976, 10816, 10037, 8480]

# %% [markdown]
# ### Denied PETITIONS DISTRIBUTION BY YEAR

# %%
denied['YEAR'].value_counts().sort_index()
# Out:
# YEAR
# 2011    25986
# 2012    18866
# 2013    10976
# 2014    10816
# 2015    10037
# 2016     8480
# Name: count, dtype: int64

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='YEAR', data=denied , order = sorted(denied['YEAR'].unique()))
plt.title('Denied Petitions Distribution by Year')
plt.xlabel('YEAR')
plt.ylabel('count')
plt.show()

# %% [markdown]
# #### Denied % Rate By Year

# %%
# Out:
# year           2011  2012  2013  2014  2015  2016
# denied rate %  7.79  4.79   2.6  2.17  1.67  1.35

# %%
denied_percent = (denied.groupby('YEAR').size()/df.groupby('YEAR').size())*100
denied_per = pd.DataFrame([denied_percent.values],index=['denied rate %'],columns=[denied_percent.index])
denied_per
# Out:
# YEAR               2011      2012      2013     2014      2015      2016
# denied rate %  7.788985  4.785082  2.598319  2.17177  1.672499  1.347531

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
plt.figure(figsize=(8,4))
sns.barplot(x = 'YEAR',y = 'denied rate %',data=denied_percent.reset_index(name='denied rate %'))
plt.title('Denied Petitions Distribution by Year')
plt.xlabel('YEAR')
plt.ylabel('denied rate %')
plt.show()

# %% [markdown]
# ## Calculate the number of petitions filed by the States

# %%
df.groupby('STATE').size()
# Out:
# STATE
# ALABAMA                   8644
# ALASKA                    1116
# ARIZONA                  40184
# ARKANSAS                 13775
# CALIFORNIA              548539
# COLORADO                 30231
# CONNECTICUT              48174
# DELAWARE                 17705
# DISTRICT OF COLUMBIA     22408
# FLORIDA                 100384
# GEORGIA                  99679
# HAWAII                    3157
# IDAHO                     3777
# ILLINOIS                154843
# INDIANA                  28230
# IOWA                     15143
# KANSAS                   12331
# KENTUCKY                 10968
# LOUISIANA                10043
# MAINE                     3132
# MARIANA ISLANDS           3069
# MARYLAND                 53145
# MASSACHUSETTS           112659
# MICHIGAN                 77868
# MINNESOTA                45864
# MISSISSIPPI               2686
# MISSOURI                 32737
# MONTANA                    644
# NEBRASKA                  8600
# NEVADA                    7004
# ...

# %%
df.columns
# Out:
# Index(['CASE_STATUS', 'YEAR', 'STATE', 'SOC_NAME', 'JOB_TITLE', 'FULL_T',
#        'PREV_WAGE', 'EMPLOYER', 'LON', 'LAT'],
#       dtype='object')

# %%
# Out:
# Index(['CASE_STATUS', 'YEAR', 'STATE', 'SOC_NAME', 'JOB_TITLE', 'FULL_T',
#        'PREV_WAGE', 'EMPLOYER', 'LON', 'LAT'],
#       dtype='object')

# %% [markdown]
# **unique stats sorted**

# %%
unique_states = np.sort(df['STATE'].unique())
print(unique_states)
# Out:
# ['ALABAMA' 'ALASKA' 'ARIZONA' 'ARKANSAS' 'CALIFORNIA' 'COLORADO'
#  'CONNECTICUT' 'DELAWARE' 'DISTRICT OF COLUMBIA' 'FLORIDA' 'GEORGIA'
#  'HAWAII' 'IDAHO' 'ILLINOIS' 'INDIANA' 'IOWA' 'KANSAS' 'KENTUCKY'
#  'LOUISIANA' 'MAINE' 'MARIANA ISLANDS' 'MARYLAND' 'MASSACHUSETTS'
#  'MICHIGAN' 'MINNESOTA' 'MISSISSIPPI' 'MISSOURI' 'MONTANA' 'NEBRASKA'
#  'NEVADA' 'NEW HAMPSHIRE' 'NEW JERSEY' 'NEW MEXICO' 'NEW YORK'
#  'NORTH CAROLINA' 'NORTH DAKOTA' 'OHIO' 'OKLAHOMA' 'OREGON' 'PENNSYLVANIA'
#  'PUERTO RICO' 'RHODE ISLAND' 'SOUTH CAROLINA' 'SOUTH DAKOTA' 'TENNESSEE'
#  'TEXAS' 'UTAH' 'VERMONT' 'VIRGINIA' 'WASHINGTON' 'WEST VIRGINIA'
#  'WISCONSIN' 'WYOMING']

# %%
# Out:
# ['ALABAMA', 'ALASKA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA', 'COLORADO', 'CONNECTICUT', 'DELAWARE', 'DISTRICT OF COLUMBIA', 'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO', 'ILLINOIS', 'INDIANA', 'IOWA', 'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MAINE', 'MARIANA ISLANDS', 'MARYLAND', 'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI', 'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE', 'NEW JERSEY', 'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA', 'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON', 'PENNSYLVANIA', 'PUERTO RICO', 'RHODE ISLAND', 'SOUTH CAROLINA', 'SOUTH DAKOTA', 'TENNESSEE', 'TEXAS', 'UTAH', 'VERMONT', 'VIRGINIA', 'WASHINGTON', 'WEST VIRGINIA', 'WISCONSIN', 'WYOMING']

# %%
# Out:
# 53

# %%
len(unique_states)
# Out:
# 53

# %%
plt.figure(figsize=(10,4))
sns.countplot(x='STATE', data=df , order = sorted(denied['STATE'].unique()))
plt.title('FILED PETITIONS BY STATE')
plt.xlabel('STATE')
plt.ylabel('FILED PETITIONS')
plt.xticks(rotation =90)
plt.show()

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# # Number of petitions denied by the state

# %% [markdown]
# __total denied petitions__

# %%
# Out:
# 85161

# %%
len(df[df['CASE_STATUS']=='DENIED'])
# Out:
# 85161

# %%
deni = df[df['CASE_STATUS']=='DENIED']
plt.figure(figsize=(10,4))
sns.countplot(x='STATE', data=deni , order = sorted(denied['STATE'].unique()))
plt.title('DENIED PETITIONS BY STATE')
plt.xlabel('STATE')
plt.ylabel('DENIED PETITIONS')
plt.xticks(rotation = 90)
plt.show()

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# ## % Rate of Denied Petitions by State

# %%
deni_percent = (deni.groupby('STATE').size()/df.groupby('STATE').size())*100
deni_per = pd.DataFrame([deni_percent.values],index=['denied rate %'],columns=[deni_percent.index])
deni_per
# Out:
# STATE           ALABAMA    ALASKA   ARIZONA  ARKANSAS CALIFORNIA  COLORADO  \
# denied rate %  4.477094  9.408602  2.565698  1.916515   3.081094  3.076312
#
# STATE         CONNECTICUT  DELAWARE DISTRICT OF COLUMBIA   FLORIDA  ...  \
# denied rate %    2.289617  1.931658             5.141021  5.044629  ...
#
# STATE         SOUTH DAKOTA TENNESSEE    TEXAS      UTAH   VERMONT  VIRGINIA  \
# denied rate %     3.476612  2.786999  2.81475  3.831607  4.166667  3.015596
#
# STATE         WASHINGTON WEST VIRGINIA WISCONSIN    WYOMING
# denied rate %   1.840125      3.583215  1.935378  10.966811
#
# [1 rows x 53 columns]

# %%
plt.figure(figsize=(10,4))
sns.barplot(x='STATE', y='denied rate %', data=deni_percent.reset_index(name='denied rate %'))
plt.title('DENIED PETITION RATE IN % BY STATE')
plt.xlabel('STATE')
plt.ylabel('DENIED PETITIONS %')
plt.xticks(rotation= 90)
plt.show()

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %% [markdown]
# #### Find out how many applied for Illinois State and how many how them are Denied

# %%
illinois_denied = (df[df['STATE']=='ILLINOIS'][df['CASE_STATUS']=='DENIED'])
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_22728\668812302.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   illinois_denied = (df[df['STATE']=='ILLINOIS'][df['CASE_STATUS']=='DENIED'])

# %%
len(illinois_denied)
# Out:
# 3612

# %% [markdown]
# #### How Many People are Certified for Job title 'CHIEF PROCESS OFFICER'  who applied for state  Illinois

# %%
certified_chief_illinois = df[df['CASE_STATUS']=='CERTIFIED'][df['JOB_TITLE']=='CHIEF PROCESS OFFICER'][df['STATE']=='ILLINOIS']
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_22728\3204266613.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   certified_chief_illinois = df[df['CASE_STATUS']=='CERTIFIED'][df['JOB_TITLE']=='CHIEF PROCESS OFFICER'][df['STATE']=='ILLINOIS']
# C:\Users\shubh\AppData\Local\Temp\ipykernel_22728\3204266613.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   certified_chief_illinois = df[df['CASE_STATUS']=='CERTIFIED'][df['JOB_TITLE']=='CHIEF PROCESS OFFICER'][df['STATE']=='ILLINOIS']

# %%
print(f'''{len(certified_chief_illinois)} petitions for the job of "CHIEF PROCESS OFFICER" in the state of illinois were certified''')
# Out:
# 2 petitions for the job of "CHIEF PROCESS OFFICER" in the state of illinois were certified

# %%
# Out:
# 2 petitions for the job of "CHIEF PROCESS OFFICER" in the state of illinois were certified

# %%
certified_chief_illinois['index'] = certified_chief_illinois.index
certified_chief_illinois[['index', 'CASE_STATUS', 'YEAR', 'SOC_NAME', 'JOB_TITLE', 'FULL_T', 'PREV_WAGE', 'EMPLOYER']]
# Out:
#            index CASE_STATUS  YEAR             SOC_NAME  \
# 1256937  1256937   CERTIFIED  2014  Management Analysts
# 1272268  1272268   CERTIFIED  2014  Management Analysts
#
#                      JOB_TITLE FULL_T  PREV_WAGE                EMPLOYER
# 1256937  CHIEF PROCESS OFFICER      Y      67080  LITTLER MENDELSON P.C.
# 1272268  CHIEF PROCESS OFFICER      Y      67080  LITTLER MENDELSON P.C.

# %%
# Out:
#          index CASE_STATUS  YEAR             SOC_NAME              JOB_TITLE  \
# 67488  1295151   CERTIFIED  2014  Management Analysts  CHIEF PROCESS OFFICER
# 68437  1311111   CERTIFIED  2014  Management Analysts  CHIEF PROCESS OFFICER
#
#       FULL_T PREV_WAGE                EMPLOYER
# 67488      Y     67080  LITTLER MENDELSON P.C.
# 68437      Y     67080  LITTLER MENDELSON P.C.

# %% [markdown]
# # Top 25 Job Titles

# %%
top_jobs= df['JOB_TITLE'].value_counts()[:25]
top_jobs
# Out:
# JOB_TITLE
# PROGRAMMER ANALYST             243357
# SOFTWARE ENGINEER              118897
# COMPUTER PROGRAMMER             68696
# SYSTEMS ANALYST                 60754
# SOFTWARE DEVELOPER              41875
# BUSINESS ANALYST                38781
# COMPUTER SYSTEMS ANALYST        34036
# TECHNOLOGY LEAD - US            28307
# SENIOR SOFTWARE ENGINEER        26617
# TECHNOLOGY ANALYST - US         26010
# ASSISTANT PROFESSOR             24436
# SENIOR CONSULTANT               24120
# CONSULTANT                      22643
# PROJECT MANAGER                 19015
# DATABASE ADMINISTRATOR          16108
# PHYSICAL THERAPIST              14203
# RESEARCH ASSOCIATE              13409
# COMPUTER PROGRAMMER ANALYST     13116
# ACCOUNTANT                      12934
# DEVELOPER                       12737
# ASSOCIATE                       12447
# ANALYST                         11644
# LEAD ENGINEER                   11012
# SENIOR SOFTWARE DEVELOPER       10031
# ...

# %%
# Out:
# PROGRAMMER ANALYST             243357
# SOFTWARE ENGINEER              118897
# COMPUTER PROGRAMMER             68696
# SYSTEMS ANALYST                 60754
# SOFTWARE DEVELOPER              41875
# BUSINESS ANALYST                38781
# COMPUTER SYSTEMS ANALYST        34036
# TECHNOLOGY LEAD - US            28307
# SENIOR SOFTWARE ENGINEER        26617
# TECHNOLOGY ANALYST - US         26010
# ASSISTANT PROFESSOR             24436
# SENIOR CONSULTANT               24120
# CONSULTANT                      22643
# PROJECT MANAGER                 19015
# DATABASE ADMINISTRATOR          16108
# PHYSICAL THERAPIST              14203
# RESEARCH ASSOCIATE              13409
# COMPUTER PROGRAMMER ANALYST     13116
# ACCOUNTANT                      12934
# DEVELOPER                       12737
# ASSOCIATE                       12447
# ANALYST                         11644
# LEAD ENGINEER                   11012
# SENIOR SOFTWARE DEVELOPER       10031
# SYSTEMS ENGINEER - US           10020
# ...

# %%
plt.figure(figsize=(10,4))
sns.barplot(y= 'count',x='JOB_TITLE',data = top_jobs.reset_index(),palette='deep')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# !!! Great Now Make Your Own Questions and Try to Answer Them !!
